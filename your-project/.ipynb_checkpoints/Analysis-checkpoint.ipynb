# %% [markdown]
# ## LIBRARIES

# %%
import numpy as np
import pandas as pd
import re
import scipy
from scipy import stats as st
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## FUNCTIONS

# %%
def general_check(df):
    """
    returns a dictionary of columns names, shape of the df, dict with columns as keys and
    number of nulls/columns
    
    Input: DataFrame
    Output:dictionary with nested dict and lists
    """
    general = {"COLNAMES":[c for c in df.columns],"SHAPE":tuple(df.shape), "TYPE":\
               {k:v for k,v in zip([c for c in df.columns],[df[c].dtype for\
                                                            c in [c for c in df.columns]])},
               "NULLS":{k:v for k,v in zip([c for c in df.columns],[df[c].isna().sum() for\
                                                            c in [c for c in df.columns]])}}
    return general


def col_uniques(df):
    """
    returns a dictionary of names of columns as keys and list of unique values of that column
    as values
    
    Input: DataFrame
    Output:dictionary
    """
    uniques = {k:v for k,v in zip([c.upper() for c in df.columns],[df[c].unique() for\
                                                           c in [c for c in df.columns]])}
    return uniques

# %% [markdown]
# ## IMPORTING FILES

# %%
mrg = pd.read_csv("NFA-and-WHI-(2014-2015).csv")
mrg.drop("Unnamed: 0",axis=1,inplace=True)
mrg.head()
# Out:
#        country                           region  population            GDP  \
# 0  Afghanistan                    Southern Asia      31.628   19300.733976
# 1      Albania       Central and Eastern Europe       2.890   12755.188400
# 2      Algeria  Middle East and Northern Africa      38.934  182051.101260
# 3       Angola               Sub-Saharan Africa      24.228   90796.125960
# 4    Argentina      Latin America and Caribbean      42.980  443691.136000
#
#    happiness_rank  happiness_score  standard_error  economy   family   health  \
# 0             153            3.575         0.03084  0.31982  0.30285  0.30335
# 1              95            4.959         0.05013  0.87867  0.80434  0.81325
# 2              68            5.605         0.05099  0.93929  1.07772  0.61766
# 3             137            4.033         0.04758  0.75778  0.86040  0.16683
# 4              30            6.574         0.04612  1.05351  1.24823  0.78723
#
#    ...  forest_land_EFProdTot  forest_land_EFNetradeTot  \
# 0  ...               1.920868                  0.299869
# 1  ...               0.479454                  0.359339
# 2  ...               3.350301                  3.389591
# 3  ...               2.511559                  0.159380
# 4  ...               9.433302                  1.103335
#
#    grazing_land_BiocapTot  grazing_land_EFConsTot  grazing_land_EFProdTot  \
# 0                5.914984                5.910276                5.704672
# 1                0.631604                0.690471                0.631604
# 2               10.670903                7.134556                4.894426
# 3               29.787594                2.324783                1.899933
# 4               77.034804               36.212114               43.624836
#
#    grazing_land_EFNetradeTot  total_BiocapTot  total_EFConsTot  \
# 0                   0.205603        15.942686        24.424655
# 1                   0.058866         3.038634         6.188639
# 2                   2.240130        21.084114        95.340572
# 3                   0.424850        55.489126        37.767605
# 4                  -7.412722       288.354829       158.584521
#
#    total_EFProdTot  total_EFNetradeTot
# 0        20.419030            4.005625
# 1         4.111402            2.077236
# 2        63.237726           32.102846
# 3        20.801248           16.966357
# 4       244.494779          -85.910257
#
# [5 rows x 43 columns]

# %%
general_check(mrg)
# Out:
# {'COLNAMES': ['country',
#   'region',
#   'population',
#   'GDP',
#   'happiness_rank',
#   'happiness_score',
#   'standard_error',
#   'economy',
#   'family',
#   'health',
#   'freedom',
#   'trust',
#   'generosity',
#   'residual',
#   'true_residual',
#   'built_up_land_BiocapTot',
#   'built_up_land_EFConsTot',
#   'built_up_land_EFProdTot',
#   'built_up_land_EFNetradeTot',
#   'carbon_BiocapTot',
#   'carbon_EFConsTot',
#   'carbon_EFProdTot',
#   'carbon_EFNetradeTot',
#   'crop_land_BiocapTot',
#   'crop_land_EFConsTot',
#   'crop_land_EFProdTot',
#   'crop_land_EFNetradeTot',
#   'fishing_ground_BiocapTot',
#   'fishing_ground_EFConsTot',
#   'fishing_ground_EFProdTot',
#   'fishing_ground_EFNetradeTot',
#   'forest_land_BiocapTot',
#   'forest_land_EFConsTot',
#   'forest_land_EFProdTot',
#   'forest_land_EFNetradeTot',
#   'grazing_land_BiocapTot',
#   'grazing_land_EFConsTot',
#   'grazing_land_EFProdTot',
#   'grazing_land_EFNetradeTot',
#   'total_BiocapTot',
#   'total_EFConsTot',
#   'total_EFProdTot',
#   'total_EFNetradeTot'],
#  'SHAPE': (142, 43),
#  'TYPE': {'country': dtype('O'),
#   'region': dtype('O'),
#   'population': dtype('float64'),
#   'GDP': dtype('float64'),
#   'happiness_rank': dtype('int64'),
#   'happiness_score': dtype('float64'),
#   'standard_error': dtype('float64'),
#   'economy': dtype('float64'),
#   'family': dtype('float64'),
#   'health': dtype('float64'),
#   'freedom': dtype('float64'),
#   'trust': dtype('float64'),
#   'generosity': dtype('float64'),
#   'residual': dtype('float64'),
#   'true_residual': dtype('float64'),
#   'built_up_land_BiocapTot': dtype('float64'),
#   'built_up_land_EFConsTot': dtype('float64'),
#   'built_up_land_EFProdTot': dtype('float64'),
#   'built_up_land_EFNetradeTot': dtype('float64'),
#   'carbon_BiocapTot': dtype('float64'),
#   'carbon_EFConsTot': dtype('float64'),
#   'carbon_EFProdTot': dtype('float64'),
#   'carbon_EFNetradeTot': dtype('float64'),
#   'crop_land_BiocapTot': dtype('float64'),
#   'crop_land_EFConsTot': dtype('float64'),
#   'crop_land_EFProdTot': dtype('float64'),
#   'crop_land_EFNetradeTot': dtype('float64'),
#   'fishing_ground_BiocapTot': dtype('float64'),
#   'fishing_ground_EFConsTot': dtype('float64'),
#   'fishing_ground_EFProdTot': dtype('float64'),
#   'fishing_ground_EFNetradeTot': dtype('float64'),
#   'forest_land_BiocapTot': dtype('float64'),
#   'forest_land_EFConsTot': dtype('float64'),
#   'forest_land_EFProdTot': dtype('float64'),
#   'forest_land_EFNetradeTot': dtype('float64'),
#   'grazing_land_BiocapTot': dtype('float64'),
#   'grazing_land_EFConsTot': dtype('float64'),
#   'grazing_land_EFProdTot': dtype('float64'),
#   'grazing_land_EFNetradeTot': dtype('float64'),
#   'total_BiocapTot': dtype('float64'),
#   'total_EFConsTot': dtype('float64'),
#   'total_EFProdTot': dtype('float64'),
#   'total_EFNetradeTot': dtype('float64')},
#  'NULLS': {'country': 0,
#   'region': 0,
#   'population': 0,
#   'GDP': 0,
#   'happiness_rank': 0,
#   'happiness_score': 0,
#   'standard_error': 0,
#   'economy': 0,
#   'family': 0,
#   'health': 0,
#   'freedom': 0,
#   'trust': 0,
#   'generosity': 0,
#   'residual': 0,
#   'true_residual': 0,
#   'built_up_land_BiocapTot': 0,
#   'built_up_land_EFConsTot': 0,
#   'built_up_land_EFProdTot': 0,
#   'built_up_land_EFNetradeTot': 0,
#   'carbon_BiocapTot': 0,
#   'carbon_EFConsTot': 0,
#   'carbon_EFProdTot': 0,
#   'carbon_EFNetradeTot': 0,
#   'crop_land_BiocapTot': 0,
#   'crop_land_EFConsTot': 0,
#   'crop_land_EFProdTot': 0,
#   'crop_land_EFNetradeTot': 0,
#   'fishing_ground_BiocapTot': 0,
#   'fishing_ground_EFConsTot': 0,
#   'fishing_ground_EFProdTot': 0,
#   'fishing_ground_EFNetradeTot': 0,
#   'forest_land_BiocapTot': 0,
#   'forest_land_EFConsTot': 0,
#   'forest_land_EFProdTot': 0,
#   'forest_land_EFNetradeTot': 0,
#   'grazing_land_BiocapTot': 0,
#   'grazing_land_EFConsTot': 0,
#   'grazing_land_EFProdTot': 0,
#   'grazing_land_EFNetradeTot': 0,
#   'total_BiocapTot': 0,
#   'total_EFConsTot': 0,
#   'total_EFProdTot': 0,
#   'total_EFNetradeTot': 0}}

# %%
#mrg["BiocapPC"] = mrg["total_BiocapTot"]/mrg["population"]

# %% [markdown]
# # Q1: Is general happiness level somehow correlated with the level of consumption of natural resources?

# %% [markdown]
# ## OVERVIEW: HEATMAP

# %%
# Compute the correlation matrix
corr = mrg.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(18, 14))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0, vmin=-1,
            square=False, linewidths=.5)

# %%
"""
It seems that there is not much correlation among the EF and Biocapacity Factors and
the variables from the happiness index. While significant correlations exist within the 2
sets themselves!
"""
# Out:
# '\nIt seems that there is not much correlation among the EF and Biocapacity Factors and\nthe variables from the happiness index. While significant correlations exist within the 2\nsets themselves!\n'

# %% [markdown]
# ## VISUALIZATION & BINNING

# %%
#Very big (China, Russia, USA etc.) countires have an enormous amount of TOT Biocapacity
#that would skew the rest of the data:
plt.figure(figsize=(12,7))
sns.boxplot(x="total_BiocapTot",y="region", data=mrg)

# %%
#COLOR based on GDP (RED = Highest), SIZE based on POPULATION

fig,ax = plt.subplots(2,2, figsize=(17,12))

plt.sca(ax[0,0])
#HAPPINESS SCORE VS TOT NATURAL RESOURCES AVAILABLE IN THE COUNTRY
sns.scatterplot(x="happiness_score",y="total_BiocapTot",hue="GDP",size="population",
                data=mrg, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("Total Biocapacity", fontweight="heavy")
plt.title("Happiness VS Available Natural Resources",fontweight="heavy")

plt.sca(ax[0,1])
#HAPPINESS SCORE VS EF of TOTAL USE OF COUNTRY's NATURAL RESOURCES FOR PRODUCTION
sns.scatterplot(x="happiness_score",y="total_EFProdTot",hue="GDP",size="population",
                data=mrg, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("EF of Total Production", fontweight="heavy")
plt.title("Happiness VS Use of Local Natural Resources",fontweight="heavy")

plt.sca(ax[1,0])
#HAPPINESS SCORE VS EF of TOTAL CONSUMPTION OF THE COUNTRY
sns.barplot(x="total_BiocapTot",y="region",data=mrg, orient="h")

plt.xlabel("Available Natural Resources", fontweight="heavy")
plt.title("World Regions",fontweight="heavy")

plt.sca(ax[1,1])
#HAPPINESS SCORE VS EF of TOTAL USE OF COUNTRY's NATURAL RESOURCES FOR PRODUCTION
sns.scatterplot(x="happiness_score",y="total_EFNetradeTot",hue="GDP",size="population",
                data=mrg, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("EF of Total Net Trade", fontweight="heavy")
plt.title("Happiness VS Net Trade of Natural Resources",fontweight="heavy")
# Out:
# Text(0.5, 1.0, 'Happiness VS Net Trade of Natural Resources')

# %% [markdown]
# ### REGRESSION on HAPPINESS BINS

# %%
#COLOR based on GDP (RED = Highest), SIZE based on POPULATION

fig,ax = plt.subplots(2,2, figsize=(17,12))

plt.sca(ax[0,0])
#HAPPINESS SCORE VS TOT NATURAL RESOURCES AVAILABLE IN THE COUNTRY
sns.regplot(x="happiness_score",y="total_BiocapTot", data=mrg, x_bins=30)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("Total Biocapacity", fontweight="heavy")
plt.title("Happiness VS Available Natural Resources",fontweight="heavy")

plt.sca(ax[0,1])
#HAPPINESS SCORE VS EF of TOTAL USE OF COUNTRY's NATURAL RESOURCES FOR PRODUCTION
sns.regplot(x="happiness_score",y="total_EFProdTot",data=mrg, x_bins=30)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("EF of Total Production", fontweight="heavy")
plt.title("Happiness VS Use of Local Natural Resources",fontweight="heavy")

plt.sca(ax[1,0])
#HAPPINESS SCORE VS EF of TOTAL CONSUMPTION OF THE COUNTRY
sns.barplot(x="total_BiocapTot",y="region",data=mrg, orient="h")

plt.xlabel("Available Natural Resources", fontweight="heavy")
plt.title("World Regions",fontweight="heavy")

plt.sca(ax[1,1])
#HAPPINESS SCORE VS EF of TOTAL USE OF COUNTRY's NATURAL RESOURCES FOR PRODUCTION
sns.regplot(x="happiness_score",y="total_EFNetradeTot",data=mrg, x_bins=30)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("EF of Total Net Trade", fontweight="heavy")
plt.title("Happiness VS Net Trade of Natural Resources",fontweight="heavy")
# Out:
# Text(0.5, 1.0, 'Happiness VS Net Trade of Natural Resources')

# %% [markdown]
# ### MANAGE OUTLIERS (BINNING)

# %%
avg = mrg["total_BiocapTot"].mean()
med = mrg["total_BiocapTot"].median()
mx = mrg["total_BiocapTot"].max()
mn = mrg["total_BiocapTot"].min()
print(avg)
print(med)
print(mx)
print(mn)

#countries with natural resources >= 3xMEAN
super_big = mrg[mrg["total_BiocapTot"]>= avg*2]
print("LENGTH SUPERBIG:",len(super_big))

#countries with natural resources  MEDIAN <= X <=3xMEAN
big = mrg[(mrg["total_BiocapTot"]>=med) & (mrg["total_BiocapTot"]<avg*2)]
print("LENGTH BIG:",len(big))

#countries with natural resources <= MEDIAN
small = mrg[(mrg["total_BiocapTot"]>avg/10) & (mrg["total_BiocapTot"]<med)]
print("LENGTH SMALL:",len(small))

#countries with natural resources < MEDIAN of SMALL COUNTRIES
super_small = mrg[mrg["total_BiocapTot"]< avg/10]
print("LENGTH SUPERSMALL:",len(super_small))

print("LENGTH CHECK:", len(mrg)-(len(super_big)+len(big)+len(small)+len(super_small)))
# Out:
# 85.62669470600986
# 23.963887205000002
# 1824.2779649999998
# 0.2591932193
# LENGTH SUPERBIG: 13
# LENGTH BIG: 58
# LENGTH SMALL: 33
# LENGTH SUPERSMALL: 38
# LENGTH CHECK: 0

# %% [markdown]
# ### SUPER BIG COUNTRIES

# %%
#COLOR based on GDP (RED = Highest), SIZE based on POPULATION

fig,ax = plt.subplots(2,2, figsize=(17,12))

plt.sca(ax[0,0])
#HAPPINESS SCORE VS TOT NATURAL RESOURCES AVAILABLE IN THE COUNTRY
sns.scatterplot(x="happiness_score",y="total_BiocapTot",hue="GDP",size="population",
                data=super_big, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("Total Biocapacity", fontweight="heavy")
plt.title("Happiness VS Available Natural Resources",fontweight="heavy")

plt.sca(ax[0,1])
#HAPPINESS SCORE VS EF of TOTAL USE OF COUNTRY's NATURAL RESOURCES FOR PRODUCTION
sns.scatterplot(x="happiness_score",y="total_EFProdTot",hue="GDP",size="population",
                data=super_big, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("EF of Total Production", fontweight="heavy")
plt.title("Happiness VS Use of Local Natural Resources",fontweight="heavy")

plt.sca(ax[1,0])
#HAPPINESS SCORE VS EF of TOTAL CONSUMPTION OF THE COUNTRY
sns.barplot(x="total_BiocapTot",y="region",data=super_big, orient="h")

plt.xlabel("Available Natural Resources", fontweight="heavy")
plt.title("World Regions",fontweight="heavy")

plt.sca(ax[1,1])
#HAPPINESS SCORE VS EF of TOTAL USE OF COUNTRY's NATURAL RESOURCES FOR PRODUCTION
sns.scatterplot(x="happiness_score",y="total_EFNetradeTot",hue="GDP",size="population",
                data=super_big, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("EF of Total Net Trade", fontweight="heavy")
plt.title("Happiness VS Net Trade of Natural Resources",fontweight="heavy")
# Out:
# Text(0.5, 1.0, 'Happiness VS Net Trade of Natural Resources')

# %% [markdown]
# ### BIG COUNTRIES

# %%
#COLOR based on GDP (RED = Highest), SIZE based on POPULATION

fig,ax = plt.subplots(2,2, figsize=(17,12))

plt.sca(ax[0,0])
#HAPPINESS SCORE VS TOT NATURAL RESOURCES AVAILABLE IN THE COUNTRY
sns.scatterplot(x="happiness_score",y="total_BiocapTot",hue="GDP",size="population",
                data=big, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("Total Biocapacity", fontweight="heavy")
plt.title("Happiness VS Available Natural Resources",fontweight="heavy")

plt.sca(ax[0,1])
#HAPPINESS SCORE VS EF of TOTAL USE OF COUNTRY's NATURAL RESOURCES FOR PRODUCTION
sns.scatterplot(x="happiness_score",y="total_EFProdTot",hue="GDP",size="population",
                data=big, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("EF of Total Production", fontweight="heavy")
plt.title("Happiness VS Use of Local Natural Resources",fontweight="heavy")

plt.sca(ax[1,0])
#HAPPINESS SCORE VS EF of TOTAL CONSUMPTION OF THE COUNTRY
sns.barplot(x="total_BiocapTot",y="region",data=big, orient="h")

plt.xlabel("Available Natural Resources", fontweight="heavy")
plt.title("World Regions",fontweight="heavy")

plt.sca(ax[1,1])
#HAPPINESS SCORE VS EF of TOTAL USE OF COUNTRY's NATURAL RESOURCES FOR PRODUCTION
sns.scatterplot(x="happiness_score",y="total_EFNetradeTot",hue="GDP",size="population",
                data=big, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("EF of Total Net Trade", fontweight="heavy")
plt.title("Happiness VS Net Trade of Natural Resources",fontweight="heavy")
# Out:
# Text(0.5, 1.0, 'Happiness VS Net Trade of Natural Resources')

# %% [markdown]
# ### SMALL COUNTRIES

# %%
#COLOR based on GDP (RED = Highest), SIZE based on POPULATION

fig,ax = plt.subplots(2,2, figsize=(17,12))

plt.sca(ax[0,0])
#HAPPINESS SCORE VS TOT NATURAL RESOURCES AVAILABLE IN THE COUNTRY
sns.scatterplot(x="happiness_score",y="total_BiocapTot",hue="GDP",size="population",
                data=small, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("Total Biocapacity", fontweight="heavy")
plt.title("Happiness VS Available Natural Resources",fontweight="heavy")

plt.sca(ax[0,1])
#HAPPINESS SCORE VS EF of TOTAL USE OF COUNTRY's NATURAL RESOURCES FOR PRODUCTION
sns.scatterplot(x="happiness_score",y="total_EFProdTot",hue="GDP",size="population",
                data=small, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("EF of Total Production", fontweight="heavy")
plt.title("Happiness VS Use of Local Natural Resources",fontweight="heavy")

plt.sca(ax[1,0])
#HAPPINESS SCORE VS EF of TOTAL CONSUMPTION OF THE COUNTRY
sns.barplot(x="total_BiocapTot",y="region",data=small, orient="h")

plt.xlabel("Available Natural Resources", fontweight="heavy")
plt.title("World Regions",fontweight="heavy")

plt.sca(ax[1,1])
#HAPPINESS SCORE VS EF of TOTAL USE OF COUNTRY's NATURAL RESOURCES FOR PRODUCTION
sns.scatterplot(x="happiness_score",y="total_EFNetradeTot",hue="GDP",size="population",
                data=small, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("EF of Total Net Trade", fontweight="heavy")
plt.title("Happiness VS Net Trade of Natural Resources",fontweight="heavy")
# Out:
# Text(0.5, 1.0, 'Happiness VS Net Trade of Natural Resources')

# %% [markdown]
# ### SUPER SMALL COUNTRIES

# %%
#COLOR based on GDP (RED = Highest), SIZE based on POPULATION

fig,ax = plt.subplots(2,2, figsize=(17,12))

plt.sca(ax[0,0])
#HAPPINESS SCORE VS TOT NATURAL RESOURCES AVAILABLE IN THE COUNTRY
sns.scatterplot(x="happiness_score",y="total_BiocapTot",hue="GDP",size="population",
                data=super_small, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("Total Biocapacity", fontweight="heavy")
plt.title("Happiness VS Available Natural Resources",fontweight="heavy")

plt.sca(ax[0,1])
#HAPPINESS SCORE VS EF of TOTAL USE OF COUNTRY's NATURAL RESOURCES FOR PRODUCTION
sns.scatterplot(x="happiness_score",y="total_EFProdTot",hue="GDP",size="population",
                data=super_small, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("EF of Total Production", fontweight="heavy")
plt.title("Happiness VS Use of Local Natural Resources",fontweight="heavy")

plt.sca(ax[1,0])
#HAPPINESS SCORE VS EF of TOTAL CONSUMPTION OF THE COUNTRY
sns.barplot(x="total_BiocapTot",y="region",data=super_small, orient="h")

plt.xlabel("Available Natural Resources", fontweight="heavy")
plt.title("World Regions",fontweight="heavy")

plt.sca(ax[1,1])
#HAPPINESS SCORE VS EF of TOTAL USE OF COUNTRY's NATURAL RESOURCES FOR PRODUCTION
sns.scatterplot(x="happiness_score",y="total_EFNetradeTot",hue="GDP",size="population",
                data=super_small, palette=cmap)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("EF of Total Net Trade", fontweight="heavy")
plt.title("Happiness VS Net Trade of Natural Resources",fontweight="heavy")
# Out:
# Text(0.5, 1.0, 'Happiness VS Net Trade of Natural Resources')

# %% [markdown]
# ### ... IS THEN MONEY TO MAKE PEOPLE HAPPY?

# %%
#SIZE based on POPULATION

fig,ax = plt.subplots(2,2, figsize=(17,12))

#HAPPINESS SCORE VS TOT GDP OF EACH OF THE 4 COUNTRY BINS
plt.sca(ax[0,0])
sns.regplot(x="happiness_score",y="GDP", data=super_big)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("Total GDP", fontweight="heavy")
plt.title("Happiness VS GDP - SUPER BIG",fontweight="heavy")

plt.sca(ax[0,1])
sns.regplot(x="happiness_score",y="GDP",data=big)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("Total GDP", fontweight="heavy")
plt.title("Happiness VS GDP - BIG",fontweight="heavy")

plt.sca(ax[1,0])
sns.regplot(x="happiness_score",y="GDP",data=small)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("Total GDP", fontweight="heavy")
plt.title("Happiness VS GDP - SMALL",fontweight="heavy")

plt.sca(ax[1,1])
sns.regplot(x="happiness_score",y="GDP",data=super_small)

plt.xlabel("Happiness Score", fontweight="heavy")
plt.ylabel("Total GDP", fontweight="heavy")
plt.title("Happiness VS GDP - SUPER SMALL",fontweight="heavy")
# Out:
# Text(0.5, 1.0, 'Happiness VS GDP - SUPER SMALL')

# %% [markdown]
# ### HOW ARE NATURAL RESOURCES, THEIR CONSUMPTION AND HAPPINESS DISTRIBUTED?

# %%
fig,ax = plt.subplots(2,2, figsize=(17,12))


plt.sca(ax[0,0])
sns.distplot(mrg["happiness_score"],bins=20)
plt.title("WORLD Happiness",fontweight="heavy")

plt.sca(ax[0,1])
sns.distplot(mrg["total_BiocapTot"],bins=20)
plt.title("WORLD Available Natural Resources",fontweight="heavy")

plt.sca(ax[1,0])
sns.distplot(mrg["total_EFProdTot"],bins=20)
plt.title("WORLD population",fontweight="heavy")

plt.sca(ax[1,1])
sns.distplot(mrg["total_EFNetradeTot"],bins=20)
plt.title("WORLD population",fontweight="heavy")
# Out:
# Text(0.5, 1.0, 'WORLD population')

# %%
#group by World Region the analyzed factors
reg = mrg.groupby(by="region").agg({"GDP":"mean","population":"sum","happiness_score":"mean",
                                    "total_BiocapTot":"sum","total_EFProdTot":"sum",
                                    "total_EFNetradeTot":"sum"})
#SORT BY AVERAGE HAPPINESS SCORE
reg.sort_values(by="happiness_score",ascending=False,inplace=True)

#COMPUTE ECOLOGICAL RESEVE/DEFICIT TO COMPARE WITH HAPPINESS
reg["total_eco_reserve/deficit"] = reg["total_BiocapTot"]-\
(reg["total_EFProdTot"]+reg["total_EFNetradeTot"])

#COMPUTE REALTIVE HAPPINESS BASED 

#reg["rel_happ_score"] = 
print(reg["total_eco_reserve/deficit"].sum())
reg
# Out:
# -7838.4372712649
#                                           GDP  population  happiness_score  \
# region
# Australia and New Zealand        1.284902e+06      23.622         7.284000
# North America                    9.002102e+06     355.037         7.273000
# Western Europe                   9.469692e+05     413.070         6.752056
# Latin America and Caribbean      2.738186e+05     600.519         6.209286
# Middle East and Northern Africa  2.363980e+05     373.573         5.654313
# Southeastern Asia                2.985330e+05     609.278         5.504750
# Eastern Asia                     3.919054e+06    1580.381         5.496250
# Central and Eastern Europe       1.340765e+05     407.138         5.323786
# Southern Asia                    3.711336e+05    1720.601         4.580857
# Sub-Saharan Africa               4.195074e+04     937.847         4.151946
#
#                                  total_BiocapTot  total_EFProdTot  \
# region
# Australia and New Zealand             313.020660       277.052675
# North America                        1687.524958      3081.340295
# Western Europe                        850.161750      1626.022005
# Latin America and Caribbean          3125.338693      1845.450221
# Middle East and Northern Africa       285.465392      1078.290183
# Southeastern Asia                     748.111135      1118.673825
# Eastern Asia                         1520.525192      5709.945228
# Central and Eastern Europe           1590.302562      1861.079052
# Southern Asia                         771.217749      1696.322247
# Sub-Saharan Africa                   1267.322556      1143.903387
#
#                                  total_EFNetradeTot  total_eco_reserve/deficit
# region
# Australia and New Zealand               -114.394816                 150.362801
# North America                           -122.342811               -1271.472526
# Western Europe                           374.225733               -1150.085988
# Latin America and Caribbean             -188.317315                1468.205788
# Middle East and Northern Africa          161.714200                -954.538990
# Southeastern Asia                        -11.750213                -358.812476
# Eastern Asia                             406.640689               -4596.060725
# Central and Eastern Europe              -146.792149                -123.984341
# Southern Asia                            115.329934               -1040.434432
# Sub-Saharan Africa                        85.035551                  38.383619
